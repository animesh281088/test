# %%
import pandas as pd

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2dea0b3431da> in <module>
# ----> 1 cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")
#
# NameError: name 'pd' is not defined

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr.tail()
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 976  LP002971   Male     Yes         4.0  Not Graduate           Yes
# 977  LP002975   Male     Yes         0.0      Graduate            No
# 978  LP002980   Male      No         0.0      Graduate            No
# 979  LP002986   Male     Yes         0.0      Graduate            No
# 980  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 976             4009             1777.0       113.0             360.0
# 977             4158              709.0       115.0             360.0
# 978             3250             1993.0       126.0             360.0
# 979             5000             2393.0       158.0             360.0
# 980             9200                0.0        98.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 976             1.0         Urban           Y
# ...

# %%
cr.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-395871c7537f> in <module>
# ----> 1 cr.shape
#
# NameError: name 'cr' is not defined

# %%
cr.describe(include = "all")
# Out:
#          Loan_ID Gender Married  Dependents Education Self_Employed  \
# count        981    957     978  956.000000       981           926
# unique       981      2       2         NaN         2             2
# top     LP002442   Male     Yes         NaN  Graduate            No
# freq           1    775     631         NaN       763           807
# mean         NaN    NaN     NaN    0.881799       NaN           NaN
# std          NaN    NaN     NaN    1.255623       NaN           NaN
# min          NaN    NaN     NaN    0.000000       NaN           NaN
# 25%          NaN    NaN     NaN    0.000000       NaN           NaN
# 50%          NaN    NaN     NaN    0.000000       NaN           NaN
# 75%          NaN    NaN     NaN    2.000000       NaN           NaN
# max          NaN    NaN     NaN    4.000000       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        981.000000         981.000000  954.000000        961.000000
# ...

# %%
#cr.Gender

# %%
#cr['Gender']

# %%
cr.ApplicantIncome.min()
# Out:
# 0

# %%
cr['ApplicantIncome'].mean()
# Out:
# 5179.795107033639

# %%
cr.isnull().sum()  # gives the null values for each columns
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#cr.isnull().sum() /      cr.shape[0]                      * 100 #  finding the percentage of null

# %%
#cr.head(20)

# %%
cr.Gender = cr.Gender.fillna("Male")

# %%
cr.Dependents.fillna(0 , inplace = True)

# %%
#cr.Dependents  = cr.Dependents.fillna(0 , inplace = True)  #  wrong

# %%
#cr.Dependents

# %%
#cr.Married.isnull().sum()

# %%
#cr.Married.fillna("Yes" , inplace = True)

# %%
#cr.Married.isnull().sum()
cr.isnull().sum()
# Out:
# Loan_ID               0
# Gender               24
# Married               3
# Dependents           25
# Education             0
# Self_Employed        55
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           27
# Loan_Amount_Term     20
# Credit_History       79
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cr.Gender.fillna("Male" , inplace = True)
cr.Married.fillna("No", inplace = True)
cr.Dependents.fillna(0, inplace = True)
cr.Self_Employed.fillna("No", inplace = True)
cr.LoanAmount.fillna(     cr.LoanAmount.mean() , inplace = True )
cr.Loan_Amount_Term.fillna(cr.Loan_Amount_Term.mean(), inplace = True)
cr.Credit_History.fillna(0 , inplace = True)

# %%
#cr.isnull().sum()

# %%
cr.head(200)
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No         0.0      Graduate            No
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# 5    LP001011    Male     Yes         2.0      Graduate           Yes
# 6    LP001013    Male     Yes         0.0  Not Graduate            No
# 7    LP001014    Male     Yes         4.0      Graduate            No
# 8    LP001018    Male     Yes         2.0      Graduate            No
# 9    LP001020    Male     Yes         1.0      Graduate            No
# 10   LP001024    Male     Yes         2.0      Graduate            No
# 11   LP001027    Male     Yes         2.0      Graduate            No
# ...

# %%
cr.replace({"Gender" : {"Male" : 0 , "Female" :1 }    ,
            "Married" :{"No"   : 0 , "Yes"  :  1} }, inplace = True)
 
# convert the categories to numbrs

# %%
#cr.head()

# %%
#cr.Self_Employed.replace({"No" : 0 , "Yes" :1 } , inplace = True)

# %%
# Ps i want to select only those people who are earning more than 3000

# %%
aa = cr.ApplicantIncome > 3000
len(aa)
# Out:
# 981

# %%
#cr.shape
# Out:
# (981, 13)

# %%
#aa

# %%
cr1 = cr[aa]

# %%
#cr1.head()

# %%
cr2 = cr[cr.ApplicantIncome > 3000 ]
cr2.shape
# Out:
# (700, 13)

# %%
# selecet only those people who are earning more than 3500 , are graduate ,and Credidt histroy is 1

# %%
cr3=cr[  (cr.ApplicantIncome >3500) &    (cr.Education =='Graduate') &      (cr.Credit_History==1) ]
#cr3.head(10)
cr3.shape
# Out:
# (376, 13)

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")

# %%
cr.Gender.value_counts()  # telll  how many   records for each level
# Out:
# Male      775
# Female    182
# Name: Gender, dtype: int64

# %%
cr.Property_Area.value_counts()
# Out:
# Semiurban    349
# Urban        342
# Rural        290
# Name: Property_Area, dtype: int64

# %%
cr.groupby("Gender").ApplicantIncome.mean()
# Out:
# Gender
# Female    4458.906593
# Male      5256.925161
# Name: ApplicantIncome, dtype: float64

# %%
#cr.groupby("Education").ApplicantIncome.median()

# %%
cr.groupby("Gender").ApplicantIncome.agg(["count" , "min" , "max" , "mean" , "median"])
# Out:
#         count  min    max         mean  median
# Gender
# Female    182    0  19484  4458.906593  3634.5
# Male      775    0  81000  5256.925161  3865.0

# %%
cr.groupby("Gender").ApplicantIncome.agg([ "max" , "mean" , "median"])
# Out:
#           max         mean  median
# Gender
# Female  19484  4458.906593  3634.5
# Male    81000  5256.925161  3865.0

# %%
cr.groupby(['Gender', 'Married']).ApplicantIncome.agg([ "max" , "mean" , "median"])
# Out:
#                   max         mean  median
# Gender Married
# Female No       18165  4394.153226    3632
#        Yes      19484  4501.736842    3625
# Male   No       37719  4912.764151    3749
#        Yes      81000  5390.440285    3917

# %%
cr.groupby(['Gender', 'Education']).ApplicantIncome.agg([ "max" , "mean" , "median"])
# Out:
#                        max         mean  median
# Gender Education
# Female Graduate      19484  4598.175676  3666.5
#        Not Graduate  18165  3852.676471  3016.0
# Male   Graduate      81000  5725.892617  4126.5
#        Not Graduate  13083  3695.446927  3333.0

# %%
#cr.groupby(['Gender', 'Education' , 'Married']).ApplicantIncome.agg([ "max" , "mean" , "median"])

# %%
# slicing of the data ( selecting the  rows and colums)

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")

# %%
cr.head(1)
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 0  LP001002   Male      No         0.0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y

# %%
cr = cr.drop(   ["Loan_ID"], axis = 1)

# %%
cr.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No         0.0      Graduate            No             5849
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
# Gender, Education , Applicant income  , loan amount

cr1  = cr.iloc[:                          ,                  [0 , 3 ,5 ,7]]  # index location
cr1.shape
# Out:
# (981, 4)

# %%
#  Gender, Education , Applicant income  , loan amount  
#  1   , 10 , 100

cr2  = cr.iloc[ [0 , 9 , 99]    ,  [0 , 3 ,5 ,7]] 
cr2
# Out:
#    Gender Education  ApplicantIncome  LoanAmount
# 0    Male  Graduate             5849         NaN
# 9    Male  Graduate            12841       349.0
# 99   Male  Graduate             1759       131.0

# %%
#cr.iloc[: , -1]  # select the last column

# %%
#  select all the records and all columns from education till property area ( both includedd)

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")

# %%
cr.head(1)
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 0  LP001002   Male      No         0.0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y

# %%
# educatuion  4
# Property area 11

# %%
cr3 =  cr.iloc[ : , [4,5,6,7,8,9,10 , 11]]
cr3.head(1)
# Out:
#   Education Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  Graduate            No             5849                0.0         NaN
#
#    Loan_Amount_Term  Credit_History Property_Area
# 0             360.0             1.0         Urban

# %%
cr4 =  cr.iloc[ : , 4: 11]
cr4.head(1)
# Out:
#   Education Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  Graduate            No             5849                0.0         NaN
#
#    Loan_Amount_Term  Credit_History
# 0             360.0             1.0

# %%
cr4 = cr.loc[:     , ["Education" ,"ApplicantIncome" ,"Credit_History"]]

# %%
cr4.head()
# Out:
#       Education  ApplicantIncome  Credit_History
# 0      Graduate             5849             1.0
# 1      Graduate             4583             1.0
# 2      Graduate             3000             1.0
# 3  Not Graduate             2583             1.0
# 4      Graduate             6000             1.0

# %%
#cr.head(10)

# %%
cr5 = cr.sort_values("ApplicantIncome") # ascending order

# %%
# cr6 = cr.sort_values("ApplicantIncome" , ascending=  False)
# cr6.head()

# %%
#  sampling ( break the data into train and test data )

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr_x = cr.iloc[:  , 1: 12]  # contains all X ( independent variable)
cr_y = cr.iloc[: , -1]  # only Y variable (dependent)

#  it conatins all the records

# %%
#cr_x.head(1)

# %%
from sklearn.model_selection import train_test_split

# %%
cr_x_train , cr_x_test , cr_y_train , cr_y_test  = train_test_split(  cr_x,   cr_y , test_size = .2)

# %%
print(cr_x_train.shape)
print(cr_y_train.shape)

print("-----------------------")
print(cr_x_test.shape)
print(cr_y_test.shape)
# Out:
# (784, 11)
# (784,)
# -----------------------
# (197, 11)
# (197,)

# %%
#cr_x_train.head()

# %%
#cr_y_train.iloc[0:5]

# %%
cr_x_train , cr_x_test , cr_y_train , cr_y_test  = train_test_split(  cr_y,   cr_x , test_size = .2) # wrong

# %%
 cr_y_train , cr_y_test , cr_x_train , cr_x_test = train_test_split(  cr_y,   cr_x , test_size = .2)

# %%
# another way to do the sampling

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")
cr.head(1)
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 0  LP001002   Male      No         0.0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y

# %%
cr = cr.drop( ["Loan_ID"] , axis = 1)

# %%
#cr.head() # this df conatins both x and y

# %%
cr.shape
# Out:
# (981, 12)

# %%
cr_train , cr_test = train_test_split(cr , test_size = .2 , random_state = 555)

# %%
#cr_train.shape

# %%
#cr_test.shape

# %%
#784 + 197

# %%
cr_x_train = cr_train.iloc[: , 0:11]
cr_y_train = cr_train.iloc[: -1]

# %%
cr_x_test = cr_test.iloc[: , 0:11]
cr_y_test = cr_test.iloc[: -1]

# %%
#cr_x_train.head()

# %%
#cr_y_train.iloc[0:5]

# %%
#cr_x_train.head()

# %%
# label encoder ( to do the label encoding...i.e convert the non -numeric data / Categorical data to Numbers)

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")

# %%
cr.Gender.fillna("Male" , inplace = True)
cr.Married.fillna("No", inplace = True)
cr.Dependents.fillna(0, inplace = True)
cr.Self_Employed.fillna("No", inplace = True)
cr.LoanAmount.fillna(     cr.LoanAmount.mean() , inplace = True )
cr.Loan_Amount_Term.fillna(cr.Loan_Amount_Term.mean(), inplace = True)
cr.Credit_History.fillna(0 , inplace = True)

# %%
#cr.isnull().sum()

# %%
cr = cr.drop(["Loan_ID"] , axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() # create a object / instance  or run it for the 1st time

# %%
#cr.head()

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")

cr.Gender.fillna("Male" , inplace = True)
cr.Married.fillna("No", inplace = True)
cr.Dependents.fillna(0, inplace = True)
cr.Self_Employed.fillna("No", inplace = True)
cr.LoanAmount.fillna(     cr.LoanAmount.mean() , inplace = True )
cr.Loan_Amount_Term.fillna(cr.Loan_Amount_Term.mean(), inplace = True)
cr.Credit_History.fillna(0 , inplace = True)


cr = cr.drop(["Loan_ID"] , axis = 1)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
#cr.head()

# %%
cr[cr.select_dtypes(include=['object']).columns]  = cr[cr.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
#cr.head()

# %%
#cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")

# %%
#cr.info()

# %%
cr = pd.read_csv(r"C:\Users\Pranjal Mishra\Documents\CreditRisk.csv")
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
cr1 = cr.iloc[: , [1 ,2  , 11]]

# %%
#cr1.head(50)

# %%
cr2 = pd.get_dummies(cr1)
#cr2.head(20)

# %%
# i want to add a column to my existing data frame

# %%
new_income = 2 *cr.ApplicantIncome

# %%
cr_new = pd.concat([ cr , new_income] , axis =1 )

# %%
cr_new.head(5)
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  ApplicantIncome
# 0             1.0         Urban           Y            11698
# ...

# %%
cr_new.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'ApplicantIncome'],
#       dtype='object')

# %%
l1 =  list(cr_new.columns)

# %%
l1[13]  = "New_Applicant_Income"

# %%
l1
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status',
#  'New_Applicant_Income']

# %%
cr_new.columns  = l1

# %%
cr_new.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  New_Applicant_Income
# 0             1.0         Urban           Y                 11698
# ...

# %%
cr.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
new_income       = 2 *cr.ApplicantIncome   
cr["New_Column"] = new_income

# %%
#cr.head()

# %%
#cr["Gender"]
